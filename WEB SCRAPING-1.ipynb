# %% [markdown]
# # 1. Write a python program to display all the header tags from ‘en.wikipedia.org/wiki/Main_Page’.

# %%
# !pip install bs4

# %%
# !pip install requests

# %%
#import required libraries
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
#Send req. to the web page 
pages =requests.get("http://en.wikipedia.org/wiki/Main_Page")
pages
# Out:
# <Response [200]>

# %%
#see the web page code downloaded
pages.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Wikipedia, the free encyclopedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"3f8d9e32-cce1-4427-888c-2c987761058f","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitle":"Main Page","wgCurRevisionId":1004593520,"wgRevisionId":1004593520,"wgArticleId":15580374,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbablyEditable":!1,"wgRel
# ...

# %%
# we will parse code by using BeautifulSoup and the parser as used here is html
soup = BeautifulSoup(pages.text,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
#First we will extract the html tag where we have first title
titles = soup.find_all(['h1','h2','h3','h4','h5','h6',])
print('List all the header tags :', *titles, sep='\n\n')
# Out:
# List all the header tags :
#
# <h1 class="firstHeading" id="firstHeading">Main Page</h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
#
# ...

# %%
titles = [titles.text for titles in soup.find_all(['h1','h2','h3','h4','h5','h6'])]
titles
# Out:
# ['Main Page',
#  "From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages',
#  'Navigation menu',
#  '\nPersonal tools\n',
#  '\nNamespaces\n',
#  '\nVariants\n',
#  '\nViews\n',
#  '\nMore\n',
#  '\nSearch\n',
#  '\nNavigation\n',
#  '\nContribute\n',
#  '\nTools\n',
#  '\nPrint/export\n',
#  '\nIn other projects\n',
#  '\nLanguages\n']

# %%
title_all = []
title_all =pd.DataFrame({})
title_all ['Headings'] = titles
title_all
# Out:
#                          Headings
# 0                       Main Page
# 1   From today's featured article
# 2                Did you know ...
# 3                     In the news
# 4                     On this day
# 5        Today's featured picture
# 6        Other areas of Wikipedia
# 7     Wikipedia's sister projects
# 8             Wikipedia languages
# 9                 Navigation menu
# 10             \nPersonal tools\n
# 11                 \nNamespaces\n
# 12                   \nVariants\n
# 13                      \nViews\n
# 14                       \nMore\n
# 15                     \nSearch\n
# 16                 \nNavigation\n
# 17                 \nContribute\n
# 18                      \nTools\n
# 19               \nPrint/export\n
# 20          \nIn other projects\n
# 21                  \nLanguages\n

# %% [markdown]
# # 2. Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of release) and make data frame.

# %%
#Top 100 highest rated movies on imdb
url = requests.get("https://www.imdb.com/list/ls055592025/")

# %%
request = url.text

# %%
soup_data = BeautifulSoup(request,'html.parser')

# %%
soup_data
# Out:
# <!DOCTYPE html>
#
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="app-id=342792525, app-argument=imdb:///list/ls055592025?src=mdot" name="apple-itunes-app"/>
# <script type="text/javascript">var IMDbTimer={starttime: new Date().getTime(),pt:'java'};</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>(function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <title>Top 100 Greatest Movies of All Time (The Ultimate List) - IMDb</title>
# <script>(function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);</script>
# <script>
#     if (typeof uet == 'function') {
#       uet("be", "LoadTitle", {wb: 1});
#     }
# </script>
# <script>
#     if (typeof uex == 'function') {
# ...

# %%
soup_data.title.text
# Out:
# 'Top 100 Greatest Movies of All Time (The Ultimate List) - IMDb'

# %%
movies = soup_data.findAll('div',{'class':'lister-item-content'})
first_movie = movies[0]

# %%
first_movie.h3.a.text
# Out:
# 'The Godfather'

# %%
first_movie.find('span',{"class":"lister-item-year text-muted unbold"}).text
# Out:
# '(1972)'

# %%
first_movie.find('span',{"class":"ipl-rating-star__rating"}).text.replace('\n','')
# Out:
# '9.2'

# %%
Name = []
Year = []
Rating = []
for i in movies:
    Name.append(i.h3.a.text)
    Year.append(i.find('span',{"class":"lister-item-year text-muted unbold"}).text)
    Rating.append(i.find('span',{"class":"ipl-rating-star__rating"}).text.replace('\n',''))

# %%
data = list(zip(Name,Year,Rating))
df = pd.DataFrame (data,columns=['Name','Year','Rating'])
df.head(100)
# Out:
#                         Name    Year Rating
# 0              The Godfather  (1972)    9.2
# 1   The Shawshank Redemption  (1994)    9.3
# 2           Schindler's List  (1993)    8.9
# 3                Raging Bull  (1980)    8.2
# 4                 Casablanca  (1942)    8.5
# ..                       ...     ...    ...
# 95               Rear Window  (1954)    8.5
# 96             The Third Man  (1949)    8.1
# 97     Rebel Without a Cause  (1955)    7.7
# 98        North by Northwest  (1959)    8.3
# 99       Yankee Doodle Dandy  (1942)    7.7
#
# [100 rows x 3 columns]

# %% [markdown]
# # 3.Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Year of release) and make data frame.

# %%
url_link = requests.get("https://www.imdb.com/list/ls009997493/")

# %%
request = url_link.text

# %%
soup_data = BeautifulSoup(request,'html.parser')

# %%
soup_data.title.text
# Out:
# 'IMDB Top 100 Hindi Movies - IMDb'

# %%
movies = soup_data.findAll('div',{'class':'lister-item mode-detail'})
first_movie = movies[0]
first_movie.h3.a.text   #name of the movie
# Out:
# 'Rang De Basanti'

# %%
first_movie.find('span',{"class":"lister-item-year text-muted unbold"}).text   #year
# Out:
# '(2006)'

# %%
first_movie.find('span',{"class":"ipl-rating-star__rating"}).text  #Rating
# Out:
# '8.1'

# %%
Name = []
Year = []
Rating = []
for i in movies:
    Name.append(i.h3.a.text)
    Year.append(i.find('span',{"class":"lister-item-year text-muted unbold"}).text)
    Rating.append(i.find('span',{"class":"ipl-rating-star__rating"}).text)

# %%
data = list(zip(Name,Year,Rating))
df = pd.DataFrame (data,columns=['Name','Year','Rating'])
df.head(100)
# Out:
#                       Name    Year Rating
# 0          Rang De Basanti  (2006)    8.1
# 1                 3 Idiots  (2009)    8.4
# 2         Taare Zameen Par  (2007)    8.4
# 3           Dil Chahta Hai  (2001)    8.1
# 4   Swades: We, the People  (2004)    8.2
# ..                     ...     ...    ...
# 95             Wake Up Sid  (2009)    7.6
# 96                Rangeela  (1995)    7.5
# 97     Shatranj Ke Khilari  (1977)    7.6
# 98      Pyaar Ka Punchnama  (2011)    7.6
# 99           Ek Hasina Thi  (2004)    7.5
#
# [100 rows x 3 columns]

# %% [markdown]
# # 4.Write a python program to scrap book name, author name, genre and book review of any 5 books from
# ‘www.bookpage.com’

# %%
page = requests.get('https://bookpage.com/reviews')
request = page.text

# %%
#soup_data = BeautifulSoup(request,'html.parser')
soup=BeautifulSoup(page.content)
soup_data.title.text
# Out:
# 'IMDB Top 100 Hindi Movies - IMDb'

# %%
first_book=soup.find('h4',class_="italic")                                       #Book Name
first_book.text.replace('\n','')
# Out:
# 'The Rose Code'

# %%
first_auth=soup.find('p',class_="sans bold")                                     #Author Name
first_auth.text.replace('\n','')
# Out:
# 'Kate Quinn'

# %%
first_genre=soup.find('p',class_="genre-links")                                   #Genre
first_genre.text.replace('\n','')
# Out:
# 'Audio / Fiction / Historical Fiction'

# %%
first_rev=soup.find('p',class_="excerpt")                                          # Short Review
first_rev.text.replace('\n','')
# Out:
# 'The Rose Code is a terrific story, brilliantly performed by Saskia Maarleveld. Or as Osla would say, it’s a real corker!'

# %%
books = soup.find_all('h4',class_="italic")
book = []
for item in books:
    book.append(item.text.strip())

# %%
authors = soup.find_all('p',class_="sans bold")
author= []  
for item in authors:
    author.append(item.text.strip())

# %%
genre = soup.find_all('p',class_="genre-links")
genres= []   
for item in genre:
    genres.append(item.text.replace('\n',''))

# %%
reviews = soup.find_all('p',class_="excerpt")
rev= []  
for item in reviews:
    rev.append(item.text.replace('\n',''))

# %%
#data = list(zip(book,authors,genre,reviews))
#df = pd.DataFrame (data,columns=['book','authors','genre','review'])
df = pd.DataFrame({})
df['book'] = book
df['Author'] = author
df['genre'] = genres
df['review'] = rev

df
# Out:
#                        book  \
# 0             The Rose Code
# 1                The Damage
# 2                ★ Blackout
# 3  ★ The Sweetness of Water
# 4         The Killing Hills
# 5             ★ The Outlier
# 6  ★ Ahmed Aziz’s Epic Year
# 7                 ★ Cultish
# 8   ★ The Tangleroot Palace
# 9               ★ Bath Haus
#
#                                               Author  \
# 0                                         Kate Quinn
# 1                                     Caitlin Wahrer
# 2  Dhonielle Clayton, Tiffany D. Jackson, Nic Sto...
# 3                                      Nathan Harris
# 4                                       Chris Offutt
# 5                                           Kai Bird
# 6                                         Nina Hamza
# 7                                     Amanda Montell
# 8                                       Marjorie Liu
# 9                                        P.J. Vernon
#
# ...

# %% [markdown]
# # 5. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have to scrape:

# %% [markdown]
# # i) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.

# %%
url = requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
url
# Out:
# <Response [200]>

# %%
htmlContent = url.content

# %%
soup = BeautifulSoup(htmlContent, 'html.parser')
title = soup.title
print(title.text)
# Out:
# ICC Ranking for ODI teams International Cricket Council

# %%
first_table= soup.find("table")
assert first_table.find("th").get_text() == "Pos"
rows = first_table.find_all("tr",)

# %%
for row in rows[1:-1]:
    cells = row.find_all(["td"])
    cells_text = [cell.get_text(strip=True) for cell in cells]
    
    display(cells_text)
# Out:
# ['1', 'New ZealandNZ', '17', '2,054', '121']
# ['2', 'AustraliaAUS', '25', '2,945', '118']
# ['3', 'IndiaIND', '29', '3,344', '115']
# ['4', 'EnglandENG', '27', '3,100', '115']
# ['5', 'South AfricaSA', '20', '2,137', '107']
# ['6', 'PakistanPAK', '24', '2,323', '97']
# ['7', 'BangladeshBAN', '27', '2,438', '90']
# ['8', 'West IndiesWI', '27', '2,222', '82']
# ['9', 'Sri LankaSL', '24', '1,876', '78']
# ['10', 'AfghanistanAFG', '17', '1,054', '62']
# ['11', 'NetherlandsNED', '7', '336', '48']
# ['12', 'IrelandIRE', '21', '897', '43']
# ['13', 'ZimbabweZIM', '15', '588', '39']
# ['14', 'ScotlandSCO', '7', '258', '37']
# ['15', 'OmanOMA', '7', '240', '34']
# ['16', 'NepalNEP', '5', '119', '24']
# ['17', 'UAEUAE', '9', '190', '21']
# ['18', 'NamibiaNAM', '6', '97', '16']
# ['19', 'United StatesUSA', '8', '93', '12']

# %% [markdown]
# # ii) Top 10 ODI Batsmen in men along with the records of their team and rating.

# %%
play_bats=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting")
play_bats
# Out:
# <Response [200]>

# %%
contant= play_bats.content

# %%
soup = BeautifulSoup(contant, 'html.parser')
title = soup.title
print(title.text)
# Out:
# Live Cricket Scores & News International Cricket Council

# %%
first_table= soup.find("table")
assert first_table.find("th").get_text() == "Pos"
rows = first_table.find_all("tr",)

# %%
for row in rows[1:-1]:
    cells = row.find_all(["td"])
    cells_text = [cell.get_text(strip=True) for cell in cells]
    
    display(cells_text)
# Out:
# ['1', 'Babar Azam', 'PAK', '865', '865 v South Africa, 07/04/2021']
# ['2', 'Virat Kohli', 'IND', '857', '911 v England, 12/07/2018']
# ['3', 'Rohit Sharma', 'IND', '825', '885 v Sri Lanka, 06/07/2019']
# ['4', 'Ross Taylor', 'NZ', '801', '841 v Bangladesh, 05/06/2019']
# ['5', 'Aaron Finch', 'AUS', '791', '798 v England, 25/06/2019']
# ['6', 'Jonny Bairstow', 'ENG', '785', '796 v India, 26/03/2021']
# ['7', 'Fakhar Zaman', 'PAK', '778', '778 v South Africa, 07/04/2021']
# ['', 'Francois du Plessis', 'SA', '778', '820 v Australia, 06/07/2019']
# ['9', 'David Warner', 'AUS', '773', '880 v Pakistan, 26/01/2017']
# ['', 'Shai Hope', 'WI', '773', '808 v Bangladesh, 17/05/2019']
# ['11', 'Quinton de Kock', 'SA', '756', '813 v Sri Lanka, 10/03/2019']
# ['12', 'Kane Williamson', 'NZ', '754', '799 v India, 09/07/2019']
# ['13', 'Imam-ul-Haq', 'PAK', '751', '768 v South Africa, 02/04/2021']
# ['14', 'Mushfiqur Rahim', 'BAN', '734', '739 v Sri Lanka, 25/05/2021']
# ...

# %% [markdown]
# # iii) Top 10 ODI bowlers along with the records of their team and rating.

# %%
odi=requests.get("https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling")
odi
# Out:
# <Response [200]>

# %%
bow_con = odi.content

# %%
soup=BeautifulSoup(bow_con,'html.parser')
title = soup.title
print(title.text)
# Out:
# Live Cricket Scores & News International Cricket Council

# %%
first_table= soup.find("table")
assert first_table.find("th").get_text() == "Pos"
rows = first_table.find_all("tr",)
rows
# Out:
# [<tr class="table-head">
#  <th class="table-head__cell u-text-right">Pos</th>
#  <th class="table-head__cell">Player</th>
#  <th class="table-head__cell">Team</th>
#  <th class="table-head__cell table-head__cell--rating">Rating</th>
#  <th class="table-head__cell u-text-right u-hide-phablet">Career Best Rating</th>
#  </tr>,
#  <tr class="rankings-block__banner">
#  <td class="rankings-block__position">1</td>
#  <td class="rankings-block__top-player-container">
#  <div class="u-flex-center u-text-left">
#  <div class="rankings-block__player-image-container rankings-block__player-image-container--large">
#  <a href="/rankings/mens/player-rankings/969">
#  <img alt="Player Image" class="rankings-block__player-image image-missing" data-error="true" data-player="969" data-size="130x150" data-widget="player-image" src="//resources.pulse.icc-cricket.com/players/130x150/Photo-Missing.png"/>
#  </a>
#  </div>
#  <div>
# ...

# %%
for row in rows[1:-1]:
    cells = row.find_all(["td"])
    cells_text = [cell.get_text(strip=True) for cell in cells]
    
    display(cells_text)
# Out:
# ['1', 'Trent Boult', 'NZ', '737', '770 v West Indies, 22/06/2019']
# ['2', 'Mehedi Hasan', 'BAN', '713', '725 v Sri Lanka, 25/05/2021']
# ['3', 'Mujeeb Ur Rahman', 'AFG', '708', '712 v Ireland, 24/01/2021']
# ['4', 'Matt Henry', 'NZ', '691', '691 v Bangladesh, 26/03/2021']
# ['5', 'Jasprit Bumrah', 'IND', '690', '841 v West Indies, 01/11/2018']
# ['6', 'Kagiso Rabada', 'SA', '666', '724 v England, 29/05/2017']
# ['7', 'Chris Woakes', 'ENG', '665', '676 v New Zealand, 14/07/2019']
# ['8', 'Josh Hazlewood', 'AUS', '660', '733 v England, 26/01/2018']
# ['9', 'Pat Cummins', 'AUS', '646', '729 v Pakistan, 12/06/2019']
# ['10', 'Mustafizur Rahman', 'BAN', '645', '695 v West Indies, 14/12/2018']
# ['11', 'Mohammad Amir', 'PAK', '638', '663 v Sri Lanka, 02/10/2019']
# ['12', 'Shaheen Afridi', 'PAK', '634', '634 v South Africa, 07/04/2021']
# ['13', 'Bhuvneshwar Kumar', 'IND', '632', '657 v West Indies, 17/10/2014']
# ['14', 'Jofra Archer', 'ENG', '627', '642 v Australia, 13/09/2020']
# ...

# %% [markdown]
# # 6. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have to scrape:

# %% [markdown]
# # i) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.

# %%
wo_url = requests.get("https://www.icc-cricket.com/rankings/womens/team-rankings/odi" )       #fetching the url
htmlContent = wo_url.content

# %%
soup = BeautifulSoup(htmlContent, 'html.parser')
title = soup.title
print(title.string)
# Out:
# ICC Ranking for ODI teams International Cricket Council

# %%
first_table= soup.find("table")
assert first_table.find("th").get_text() == "Pos"
rows = first_table.find_all("tr",)

# %%
for row in rows[1:-1]:
    cells = row.find_all(["td"])
    cells_text = [cell.get_text(strip=True) for cell in cells]
    
    display(cells_text)
# Out:
# ['1', 'AustraliaAUS', '18', '2,955', '164']
# ['2', 'South AfricaSA', '24', '2,828', '118']
# ['3', 'EnglandENG', '17', '1,993', '117']
# ['4', 'IndiaIND', '20', '2,226', '111']
# ['5', 'New ZealandNZ', '21', '1,947', '93']
# ['6', 'West IndiesWI', '12', '1,025', '85']
# ['7', 'PakistanPAK', '15', '1,101', '73']
# ['8', 'BangladeshBAN', '5', '306', '61']
# ['9', 'Sri LankaSL', '11', '519', '47']

# %% [markdown]
# # ii) Top 10 women’s ODI players along with the records of their team and rating.

# %%
wo_ply = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi" )       #fetching the url
htmlContent = wo_ply.content

# %%
soup = BeautifulSoup(htmlContent, 'html.parser')
title = soup.title
print(title.string)
# Out:
# ICC ODI Match Player Rankings International Cricket Council

# %%
first_table= soup.find("table")
assert first_table.find("th").get_text() == "Pos"
rows = first_table.find_all("tr",)

# %%
for row in rows[1:-1]:
    cells = row.find_all(["td"])
    cells_text = [cell.get_text(strip=True) for cell in cells]
    
    display(cells_text)
# Out:
# ['2', 'Lizelle Lee', 'SA', '758']
# ['3', 'Alyssa Healy', 'AUS', '756']
# ['4', 'Stafanie Taylor', 'WI', '746']
# ['5', 'Meg Lanning', 'AUS', '723']
# ['6', 'Amy Satterthwaite', 'NZ', '715']
# ['7', 'Smriti Mandhana', 'IND', '710']
# ['8', 'Mithali Raj', 'IND', '709']
# ['9This player has moved up in the rankings since the previous rankings update',
#  'Natalie Sciver',
#  'ENG',
#  '685']

# %% [markdown]
# # iii) Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
wo_bowler = requests.get("https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder" )       #fetching the url
htmlContent = wo_bowler.content

# %%
soup = BeautifulSoup(htmlContent, 'html.parser')
title = soup.title
print(title.string)
# Out:
# Live Cricket Scores & News International Cricket Council

# %%
first_table= soup.find("table")
assert first_table.find("th").get_text() == "Pos"
rows = first_table.find_all("tr",)

# %%
for row in rows[1:-1]:
    cells = row.find_all(["td"])
    cells_text = [cell.get_text(strip=True) for cell in cells]
    
    display(cells_text)
# Out:
# ['1', 'Marizanne Kapp', 'SA', '418', '418 v India, 17/03/2021']
# ['This player has moved down in the rankings since the previous rankings update',
#  'Ellyse Perry',
#  'AUS',
#  '418',
#  '548 v West Indies, 11/09/2019']
# ['3', 'Stafanie Taylor', 'WI', '410', '559 v New Zealand, 10/10/2013']
# ['4', 'Natalie Sciver', 'ENG', '349', '349 v New Zealand, 28/02/2021']
# ['5', 'Deepti Sharma', 'IND', '343', '397 v South Africa, 09/10/2019']
# ['6', 'Jess Jonassen', 'AUS', '307', '308 v West Indies, 11/09/2019']
# ['7', 'Ashleigh Gardner', 'AUS', '252', '256 v New Zealand, 04/04/2021']
# ['8This player has moved up in the rankings since the previous rankings update',
#  'Dane van Niekerk',
#  'SA',
#  '243',
#  '421 v Sri Lanka, 11/02/2019']
# ['9This player has moved down in the rankings since the previous rankings update',
#  'Sophie Devine',
#  'NZ',
#  '242',
#  '305 v Australia, 05/10/2020']
# ['10This player has moved down in the rankings since the previous rankings update',
# ...

# %% [markdown]
# # 7. Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in. The scraped data should include Product Name, Price, Image URL and Average Rating.

# %%
def Amazon_mobiles(url):
    resource_7 = requests.get(url)
    soup_7 = BeautifulSoup(resource_7.text,'html.parser')
    
    Products = []
    product_name = soup_7.find_all('span',class_='a-size-base-plus a-color-base a-text-normal')
    for i in product_name:
        Products.append(i.text)
    #print(Products)   
    Price = []
    product_price = soup_7.find_all('span',class_='a-price-whole')
    for i in product_price:
        Price.append(i.text)
    #print(Price)
    Image_URL = []
    Imagelink = soup_7.find_all('div',class_='a-section aok-relative s-image-square-aspect')
    for i in Imagelink:
        Image_URL.append(i.find('img').attrs['src'])
    
    Average_Rating = []
    Ratings = []
    ratings = soup_7.find_all('span',class_='a-icon-alt')
    for i in ratings:
        Ratings.append(i.text)
    Ratings = Ratings
    for j in Ratings:
        Average_Rating.append(j[0:3])

    import pandas as pd       
    Amazon_Mobile_Products = pd.DataFrame({})

    Amazon_Mobile_Products['Products'] = Products[:10]
    Amazon_Mobile_Products['Price'] = Price[:10]
    Amazon_Mobile_Products['Image_URL'] = Image_URL[:10]
    Amazon_Mobile_Products['Average_Rating'] = Average_Rating[:10]
    return(Amazon_Mobile_Products)

# %%
df=Amazon_mobiles('https://www.amazon.in/Smartphones-%E2%82%B910-000-%E2%82%B920-Basic-Mobiles/s?rh=n%3A1805560031%2Cp_36%3A1318506031')

# %%
df
# Out:
#                                             Products   Price  \
# 0  Redmi Note 10 (Aqua Green, 6GB RAM, 128GB Stor...  14,499
# 1  Redmi Note 10 (Aqua Green, 4GB RAM, 64GB Stora...  12,499
# 2  Redmi Note 10 (Shadow Black, 4GB RAM, 64GB Sto...  12,499
# 3  Redmi Note 9 (Arctic White, 4GB RAM, 64GB Stor...  10,999
# 4  Redmi 9 Power (Blazing Blue, 4GB RAM, 64GB Sto...  10,499
# 5  Redmi Note 9 (Pebble Grey, 4GB RAM 64GB Storag...  10,999
# 6  Redmi Note 10 (Frost White, 4GB RAM, 64GB Stor...  12,499
# 7  Redmi Note 9 (Aqua Green, 4GB RAM, 64GB Storag...  10,999
# 8  Redmi 9 Power (Mighty Black 4GB RAM 64GB Stora...  10,499
# 9  Samsung Galaxy M31 (Ocean Blue, 8GB RAM, 128GB...  16,999
#
#                                            Image_URL Average_Rating
# 0  https://m.media-amazon.com/images/I/71-BcSc9rh...            4.1
# 1  https://m.media-amazon.com/images/I/71OGzLCrjZ...            4.1
# 2  https://m.media-amazon.com/images/I/71QY6JV6Fh...            4.1
# ...

# %% [markdown]
# # 8. Write a python program to extract information about the local weather from the National Weather Service website of USA, https://www.weather.gov/ for the city, San Francisco. You need to extract data about 7 day extended forecast display for the city. The data should include period, short description, temperature and description.

# %%
page = requests.get('https://forecast.weather.gov/MapClick.php?lat=37.777120000000025&lon=-122.41963999999996#.YJedFWYzY1I')
page
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(page.content)

# %%
first_des=soup.find('p',class_="short-desc")
first_des.text
# Out:
# 'Sunny thenSunny andBreezy'

# %%
first_temp=soup.find('p',class_="temp temp-low")
first_temp.text
# Out:
# 'Low: 57 °F'

# %%
first_det=soup.find('div',class_="col-sm-10 forecast-text")
first_det.text
# Out:
# 'Sunny, with a high near 87. Breezy, with a west wind 7 to 12 mph increasing to 18 to 23 mph in the afternoon. Winds could gust as high as 29 mph. '

# %%
day = soup.find_all('p',class_="period-name")
  
for item in day:
  print(item.text.strip())
# Out:
# Today
# Tonight
# Friday
# FridayNight
# Saturday
# SaturdayNight
# Sunday
# SundayNight
# Monday

# %%
desc = soup.find_all('p',class_="short-desc")
  
for item in desc:
  print(item.text.strip())
# Out:
# Sunny thenSunny andBreezy
# Mostly Clear
# Sunny thenSunny andBreezy
# Mostly Clear
# Sunny thenSunny andBreezy
# Mostly Clearand Breezythen MostlyClear
# Sunny
# Partly Cloudy
# Mostly Sunny

# %%
temp = soup.find_all('div',class_="tombstone-container")
  
for item in temp:
  print(item.text)
# Out:
# Today
# Sunny thenSunny andBreezyHigh: 87 °F
#
# Tonight
# Mostly ClearLow: 57 °F
#
# Friday
# Sunny thenSunny andBreezyHigh: 76 °F
#
# FridayNight
# Mostly ClearLow: 56 °F
#
# Saturday
# Sunny thenSunny andBreezyHigh: 73 °F
#
# SaturdayNight
# Mostly Clearand Breezythen MostlyClearLow: 56 °F
#
# Sunday
# SunnyHigh: 71 °F
#
# SundayNight
# Partly CloudyLow: 56 °F
#
# Monday
# Mostly SunnyHigh: 69 °F

# %%
detail_desc = soup.find_all('div',class_="col-sm-10 forecast-text")
  
for item in detail_desc:
  print(item.text)
# Out:
# Sunny, with a high near 87. Breezy, with a west wind 7 to 12 mph increasing to 18 to 23 mph in the afternoon. Winds could gust as high as 29 mph.
# Mostly clear, with a low around 57. West southwest wind 16 to 21 mph decreasing to 10 to 15 mph in the evening. Winds could gust as high as 26 mph.
# Sunny, with a high near 76. Breezy, with a west southwest wind 10 to 15 mph increasing to 17 to 22 mph in the afternoon. Winds could gust as high as 29 mph.
# Mostly clear, with a low around 56. West southwest wind 13 to 18 mph, with gusts as high as 24 mph.
# Sunny, with a high near 73. Breezy, with a west southwest wind 16 to 22 mph, with gusts as high as 29 mph.
# Mostly clear, with a low around 56. Breezy.
# Sunny, with a high near 71.
# Partly cloudy, with a low around 56.
# Mostly sunny, with a high near 69.
# Mostly cloudy, with a low around 58.
# Mostly sunny, with a high near 68.
# Partly cloudy, with a low around 57.
# Mostly sunny, with a high near 68.

# %%
data = list(zip(day,desc,detail_desc))
df = pd.DataFrame (data,columns=['day','desc','detail_desc'])

# %%
df
# Out:
#                      day                                               desc  \
# 0        [Today, [], []]            [Sunny then, [], Sunny and, [], Breezy]
# 1      [Tonight, [], []]                                     [Mostly Clear]
# 2       [Friday, [], []]            [Sunny then, [], Sunny and, [], Breezy]
# 3    [Friday, [], Night]                                     [Mostly Clear]
# 4     [Saturday, [], []]            [Sunny then, [], Sunny and, [], Breezy]
# 5  [Saturday, [], Night]  [Mostly Clear, [], and Breezy, [], then Mostly...
# 6       [Sunday, [], []]                                            [Sunny]
# 7    [Sunday, [], Night]                                    [Partly Cloudy]
# 8       [Monday, [], []]                                     [Mostly Sunny]
#
#                                          detail_desc
# 0  [Sunny, with a high near 87. Breezy, with a we...
# 1  [Mostly clear, with a low around 57. West sout...
# ...

# %% [markdown]
# # 9. Write a python program to scrape fresher job listings from ‘https://internshala.com/’. It should include job title, company name, CTC, and apply date.

# %%
def job(url):
    resource_9 = requests.get(url)
    soup_9 = BeautifulSoup(resource_9.content,'html.parser')
   
    Job_title = []
    title = soup_9.find_all('div',class_='heading_4_5 profile')
    for i in title:
        Job_title.append(i.text.replace('\n',''))
   
    Company = []
    comp = soup_9.find_all('div',class_='heading_6 company_name')
    for i in comp:
        Company.append(i.text.replace('\n',''))
   
    CTC = []
    ctc = soup_9.find_all('div',class_='item_body')
    for i in range(1,120,3):
        CTC.append(ctc[i].text.replace('\n',''))
   
    Apply_Date = []
    date = soup_9.find_all('div',class_='item_body')
    for i in range(2,120,3):
        Apply_Date.append(date[i].text)
       
    Fresher_Jobs = pd.DataFrame()
   
    Fresher_Jobs['Job_title'] = Job_title
    Fresher_Jobs['Company'] = Company
    Fresher_Jobs['CTC'] = CTC
    Fresher_Jobs['Apply_Date'] = Apply_Date
    return(Fresher_Jobs)

# %%
job('https://internshala.com/fresher-jobs')
# Out:
#                                             Job_title  \
# 0                            Web Analytics Developer
# 1              Junior Social Media Marketing Manager
# 2            Junior Social Media Marketing Associate
# 3   Business Development Manager (Digital Marketin...
# 4                     Business Development Executive
# 5                                         Accountant
# 6                                 Research Associate
# 7          Assistant Coordinator - Tender Department
# 8   Customer Relationship Manager (Publishing Cons...
# 9                    Executive Assistant To Director
# 10                       Learning Consultant - Sales
# 11                         School/Teacher Consultant
# 12                                  Junior Recruiter
# 13                                Software Developer
# 14     Business Development Executive (Inside Sales)
# 15                                     Web Developer
# 16                                   Order Processor
# ...

# %% [markdown]
# # 10. Write a python program to scrape house details from mentioned url. It should include house title, location, area, emi and price https://www.nobroker.in/property/sale/bangalore/Electronic%20City?type=BHK4&searchParam=W3sibGF0IjoxMi44NDUyMTQ1LCJsb24iOjc3LjY2MDE2OTUsInBsYWNlSWQiOiJDaElKdy1GUWQ0cHNyanNSSGZkYXpnXzhYRW8iLCJwbGFjZU5hbWUiOiJFbGVjdHJvbmljIENpdHkifV0=&propertyAge=0&radius=2.0"

# %%
loc=requests.get("https://www.nobroker.in/flats-for-sale-in-btm_layout_bangalore")
#content = loc.text

# %%
soup_data = BeautifulSoup(loc.content,'html.parser')
soup_data.title.text
# Out:
# 'Apartments in BTM Layout | Flats for Sale in BTM Layout Bangalore - NoBroker'

# %%
title = []

tit = soup_data.find_all('h2',{'class':'heading-6 font-semi-bold nb__1AShY'})

for i in tit:
    title.append(i.text)
title
# Out:
# ['3 BHK Apartment  For Sale  In Pristine Residency In Btm 2nd Stage ',
#  '3 BHK Apartment  For Sale  In Chamundi Emerald In Btm Layout ',
#  '2 BHK Apartment  For Sale  In Ansal Forte In Roopena Agrahara ',
#  '2 BHK Flat  For Sale  In Sri Tirumala Dwell In Btm Layout ',
#  '3 BHK Flat  For Sale  In Kalpavriksha Apartments In Btm Layout ',
#  '2 BHK Flat  For Sale  In Ashraya Residency In Btm Layout 1 ',
#  '2 BHK Flat  For Sale  In Btm 2nd Stage ',
#  '3 BHK Apartment  For Sale  In Sms Residency In Btm 2nd Stage ',
#  '3 BHK Apartment  For Sale  In Vinayak Sai Residency In Btm Layout 1 ',
#  '1 BHK In Independent House  For Sale  In Btm Layout ']

# %%
location = []

loc = soup_data.find_all('div',{'class':'nb__2CMjv'})

for i in loc:
    location.append(i.text)
location
# Out:
# ['Pristine Residency\xa0 Near Vega City Mall',
#  'Chamundi Emerald\xa0 Chamundi Emerald, Industrial Area, Stage 2, BTM Layout, Bengaluru, Karnataka 560076, India',
#  'Ansal Forte\xa0 1st Main Road Hosur Road Roopena Agrahara Bengaluru Karnataka 560068',
#  '35th Main, 7th Cross Rd, KAS Officers Colony, BTM Layout 2nd Stage, Bangalore',
#  'Thaverekere Main Road, Kalpavriksha residency, BTM Layout',
#  'Ashraya Residency, 27th Main, 3rd Cross, BTM Layout 1st Stage. Bengaluru, Karnataka India, Jay Bheema Nagar, 1st Stage, BTM Layout 1, Bengaluru, Karnataka 560068, India',
#  'Standalone Building, 6th Main Rd, Near Mico Layout Police Station',
#  'Sms Residency\xa0 SMS Residency, 36, 7th Main Rd, NS Palya, Stage 2, BTM 2nd Stage, Bengaluru, Karnataka 560076, India',
#  'Vinayak Sai Residency\xa0 7, 9th A Main Rd, Maruthi HBCS Layout, 1st Stage, BTM Layout 1, Bengaluru, Karnataka 560029, India',
#  'Independent House, Stage 2, near Mico Layout Police Station']

# %%
area = []

ar = soup_data.find_all('div',{'class':'nb__3oNyC'})

for i in ar:
    area.append(i.text)
area
# Out:
# ['1,300 sqft',
#  '1,300 sqft',
#  '1,528 sqft',
#  '1,000 sqft',
#  '1,579 sqft',
#  '1,220 sqft',
#  '1,400 sqft',
#  '1,460 sqft',
#  '1,800 sqft',
#  '600 sqft']

# %%
emi = []

amt = soup_data.find_all('div',{'class':'font-semi-bold heading-6'})

for i in range(1,len(amt),3):
    emi.append(amt[i].text)
emi
# Out:
# ['₹41,266/Month',
#  '₹41,839/Month',
#  '₹42,985/Month',
#  '₹25,218/Month',
#  '₹63,045/Month',
#  '₹42,985/Month',
#  '₹34,388/Month',
#  '₹46,424/Month',
#  '₹68,777/Month',
#  '₹65,911/Month']

# %%
price = []

prc = soup_data.find_all('div',{'class':'font-semi-bold heading-6'})

for i in range(2,len(prc),3):
    price.append(prc[i].text)
price
# Out:
# ['₹72 Lacs',
#  '₹73 Lacs',
#  '₹75 Lacs',
#  '₹44 Lacs',
#  '₹1.1 Crores',
#  '₹75 Lacs',
#  '₹60 Lacs',
#  '₹81 Lacs',
#  '₹1.2 Crores',
#  '₹1.15 Crores']

# %%
df = pd.DataFrame()
df['Title'] = title
df['Location'] = location
df['Area'] = area
df['EMI'] = emi
df['Price'] = price

df
# Out:
#                                                Title  \
# 0  3 BHK Apartment  For Sale  In Pristine Residen...
# 1  3 BHK Apartment  For Sale  In Chamundi Emerald...
# 2  2 BHK Apartment  For Sale  In Ansal Forte In R...
# 3  2 BHK Flat  For Sale  In Sri Tirumala Dwell In...
# 4  3 BHK Flat  For Sale  In Kalpavriksha Apartmen...
# 5  2 BHK Flat  For Sale  In Ashraya Residency In ...
# 6            2 BHK Flat  For Sale  In Btm 2nd Stage
# 7  3 BHK Apartment  For Sale  In Sms Residency In...
# 8  3 BHK Apartment  For Sale  In Vinayak Sai Resi...
# 9  1 BHK In Independent House  For Sale  In Btm L...
#
#                                             Location        Area  \
# 0            Pristine Residency  Near Vega City Mall  1,300 sqft
# 1  Chamundi Emerald  Chamundi Emerald, Industrial...  1,300 sqft
# 2  Ansal Forte  1st Main Road Hosur Road Roopena ...  1,528 sqft
# 3  35th Main, 7th Cross Rd, KAS Officers Colony, ...  1,000 sqft
# ...
